# %% [markdown]
# # Single View - Trainset - Exploratory Data Analysis

# %%
import plotly.express as px

from src.utils import load_dataset

# %%
trainset = load_dataset("trainset", data_path="../data/interim")
transac = load_dataset('transac', data_path="../data/interim")
# Out:
# The file ../data/interim/trainset_2022-01-28.parquet is loaded...
#
# The file ../data/interim/transac_2022-01-28.parquet is loaded...

# %%
trainset.head(2)
# Out:
#    user_id  frequency  volume_sum most_recent_purchase first_purchase  \
# 0    17924          5          99           2011-02-14     2010-12-01
# 1    14688         15        2764           2011-08-02     2010-12-01
#
#    recency  customer_age    aov  historic_clv  mean_days_between_purchases  \
# 0     75.0         273.0   7.28          36.4                    24.666667
# 1    244.0         273.0  31.18         467.7                    17.428571
#
#   value_segment
# 0       3 - low
# 1      1 - high

# %%
transac.head(2)
# Out:
#    user_id   timestamp  total_price  volume       date
# 0    17924  2010-12-01         9.30      60 2010-12-01
# 1    14688  2010-12-01        33.35     454 2010-12-01

# %%
transac['total_price'].quantile(q=[0.01, 0.05, 0.1, 0.5, 0.9, 0.95, 0.99, 0.995, 0.999, 0.9995, 1])
# Out:
# 0.0100        0.83000
# 0.0500        2.52000
# 0.1000        4.95000
# 0.5000       42.28000
# 0.9000      143.29000
# 0.9500      193.65000
# 0.9900      364.61100
# 0.9950      529.17600
# 0.9990     2687.16055
# 0.9995     4482.71055
# 1.0000    40278.90000
# Name: total_price, dtype: float64

# %%
px.scatter(data_frame=trainset.query("aov<1000"), x="frequency", y="aov")

# %%
trainset['frequency'].value_counts(normalize=True)
# Out:
# 1     0.374702
# 2     0.200595
# 3     0.129167
# 4     0.075893
# 5     0.051190
# 6     0.038988
# 7     0.024405
# 8     0.023214
# 9     0.016071
# 10    0.011012
# 11    0.008631
# 14    0.007440
# 12    0.006250
# 13    0.005060
# 15    0.004762
# 16    0.003274
# 17    0.002381
# 20    0.001786
# 19    0.001786
# 18    0.001488
# 25    0.001488
# 29    0.001190
# 22    0.000893
# 34    0.000893
# 24    0.000893
# 37    0.000595
# 21    0.000595
# 23    0.000595
# 28    0.000595
# 32    0.000595
# 54    0.000298
# 62    0.000298
# 27    0.000298
# 65    0.000298
# 51    0.000298
# 30    0.000298
# 74    0.000298
# 44    0.000298
# 90    0.000298
# 63    0.000298
# 70    0.000298
# 31    0.000298
# Name: frequency, dtype: float64
